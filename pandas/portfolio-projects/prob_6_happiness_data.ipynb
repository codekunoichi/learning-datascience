# %% [markdown]
# ## Happiness Report Analysis
#
# 1. Data is obtained from the following dataset. [Kaggle World Happiness Report](https://www.kaggle.com/datasets/unsdsn/world-happiness)
# 2. Try to answer the following questions
#
# - What countries or regions rank the highest in overall happiness and each of the six factors contributing to happiness?
# - How did country ranks or scores change between the 2015 and 2016 as well as the 2016 and 2017 reports?
# - Did any country experience a significant increase or decrease in happiness?
#
# Steps
# 1. Load the data for 2015 till 2019
# 2. Clean the data and concat all years
# 3. Identify top twenty country's by each six factors
# 4. Plot each country year by year

# %%
import pandas as pd 

data_2015 = pd.read_csv('../data-files/happiness_data/2015.csv')
data_2016 = pd.read_csv('../data-files/happiness_data/2016.csv')
data_2017 = pd.read_csv('../data-files/happiness_data/2017.csv')
data_2018 = pd.read_csv('../data-files/happiness_data/2018.csv')
data_2019 = pd.read_csv('../data-files/happiness_data/2019.csv')

# %%
data_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
data_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
data_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
data_2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
data_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %% [markdown]
# - Observing the data set and the changes in column names, first we will add a column for year to each of the data set.
# - Then we will normalize the data set to have the same column name across each year's data set before we will concatenate them.
# - Then we will trend the year over year statistics

# %%
# Let us add the year to each of the dataframe for the year.
data_2015['year'] = 2015
data_2016['year'] = 2016
data_2017['year'] = 2017
data_2018['year'] = 2018
data_2019['year'] = 2019
data_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %% [markdown]
# ### Normalize columns
# - Normalize the column names for each of the similar looking column names across the years
# - Rename for each year the columns to the same name.
# - Keep the following for analysis
#
# 1. Country
# 2. Region
# 3. Happiness Rank
# 4. Happiness Score
# 5. Standard Error
# 6. GDP per capita
# 7. Family
# 8. Health Life Expectancy
# 9. Freedom
# 10. Trust Govt Corruption
# 11. Generosity
#
# #### Order them all as follows:
# 1. Happiness Rank
# 2. Country or region
# 3. Happiness Score
# 4. GDP per Capita
# 5. Family
# 6. Health Life Expectancy
# 7. Freedom
# 8. Generosity
# 9. Trust Govt Corruption
# 10. year

# %%
# Define the desired column order
desired_order = ['Happiness Rank', 'Country', 'Happiness Score', 'GDP per Capita', 'Family', 'Health Life Expectancy', 'Freedom', 'Generosity', 'Trust Govt Corruption', 'year']

# %%
data_2015 = data_2015.rename(columns={'Economy (GDP per Capita)': 'GDP per Capita', 'Health (Life Expectancy)': 'Health Life Expectancy', 'Trust (Government Corruption)': 'Trust Govt Corruption'})
data_2015 = data_2015.drop(['Region', 'Standard Error', 'Dystopia Residual'], axis=1)
data_2015 = data_2015[desired_order]
data_2015.head()
# Out:
#    Happiness Rank      Country  Happiness Score  GDP per Capita   Family  \
# 0               1  Switzerland            7.587         1.39651  1.34951
# 1               2      Iceland            7.561         1.30232  1.40223
# 2               3      Denmark            7.527         1.32548  1.36058
# 3               4       Norway            7.522         1.45900  1.33095
# 4               5       Canada            7.427         1.32629  1.32261
#
#    Health Life Expectancy  Freedom  Generosity  Trust Govt Corruption  year
# 0                 0.94143  0.66557     0.29678                0.41978  2015
# 1                 0.94784  0.62877     0.43630                0.14145  2015
# 2                 0.87464  0.64938     0.34139                0.48357  2015
# 3                 0.88521  0.66973     0.34699                0.36503  2015
# 4                 0.90563  0.63297     0.45811                0.32957  2015

# %%
data_2016 = data_2016.rename(columns={'Economy (GDP per Capita)': 'GDP per Capita', 'Health (Life Expectancy)': 'Health Life Expectancy', 'Trust (Government Corruption)': 'Trust Govt Corruption'})
data_2016 = data_2016.drop(['Region', 'Lower Confidence Interval', 'Upper Confidence Interval', 'Dystopia Residual'], axis=1)
data_2016 = data_2016[desired_order]
data_2016.head()
# Out:
#    Happiness Rank      Country  Happiness Score  GDP per Capita   Family  \
# 0               1      Denmark            7.526         1.44178  1.16374
# 1               2  Switzerland            7.509         1.52733  1.14524
# 2               3      Iceland            7.501         1.42666  1.18326
# 3               4       Norway            7.498         1.57744  1.12690
# 4               5      Finland            7.413         1.40598  1.13464
#
#    Health Life Expectancy  Freedom  Generosity  Trust Govt Corruption  year
# 0                 0.79504  0.57941     0.36171                0.44453  2016
# 1                 0.86303  0.58557     0.28083                0.41203  2016
# 2                 0.86733  0.56624     0.47678                0.14975  2016
# 3                 0.79579  0.59609     0.37895                0.35776  2016
# 4                 0.81091  0.57104     0.25492                0.41004  2016

# %%
data_2017 = data_2017.rename(columns={'Happiness.Rank': 'Happiness Rank', 'Happiness.Score' : 'Happiness Score', 'Economy..GDP.per.Capita.': 'GDP per Capita', 'Health..Life.Expectancy.': 'Health Life Expectancy', 'Trust..Government.Corruption.': 'Trust Govt Corruption', 'Dystopia.Residual' : 'Dystopia Residual'})
data_2017 = data_2017.drop(['Whisker.high', 'Whisker.low', 'Dystopia Residual'], axis=1)
data_2017 = data_2017[desired_order]
data_2017.head()
# Out:
#    Happiness Rank      Country  Happiness Score  GDP per Capita    Family  \
# 0               1       Norway            7.537        1.616463  1.533524
# 1               2      Denmark            7.522        1.482383  1.551122
# 2               3      Iceland            7.504        1.480633  1.610574
# 3               4  Switzerland            7.494        1.564980  1.516912
# 4               5      Finland            7.469        1.443572  1.540247
#
#    Health Life Expectancy   Freedom  Generosity  Trust Govt Corruption  year
# 0                0.796667  0.635423    0.362012               0.315964  2017
# 1                0.792566  0.626007    0.355280               0.400770  2017
# 2                0.833552  0.627163    0.475540               0.153527  2017
# 3                0.858131  0.620071    0.290549               0.367007  2017
# 4                0.809158  0.617951    0.245483               0.382612  2017

# %%
data_2018 = data_2018.rename(columns={'Country or region': 'Country', 'Overall rank': 'Happiness Rank', 'Score' : 'Happiness Score', 'GDP per capita': 'GDP per Capita', 'Healthy life expectancy': 'Health Life Expectancy', 'Perceptions of corruption': 'Trust Govt Corruption', 'Freedom to make life choices' : 'Freedom', 'Social support':'Family'})
data_2018 = data_2018[desired_order]
data_2018.head()
# Out:
#    Happiness Rank      Country  Happiness Score  GDP per Capita  Family  \
# 0               1      Finland            7.632           1.305   1.592
# 1               2       Norway            7.594           1.456   1.582
# 2               3      Denmark            7.555           1.351   1.590
# 3               4      Iceland            7.495           1.343   1.644
# 4               5  Switzerland            7.487           1.420   1.549
#
#    Health Life Expectancy  Freedom  Generosity  Trust Govt Corruption  year
# 0                   0.874    0.681       0.202                  0.393  2018
# 1                   0.861    0.686       0.286                  0.340  2018
# 2                   0.868    0.683       0.284                  0.408  2018
# 3                   0.914    0.677       0.353                  0.138  2018
# 4                   0.927    0.660       0.256                  0.357  2018

# %%
data_2019 = data_2019.rename(columns={'Country or region': 'Country', 'Overall rank': 'Happiness Rank', 'Score' : 'Happiness Score', 'GDP per capita': 'GDP per Capita', 'Healthy life expectancy': 'Health Life Expectancy', 'Perceptions of corruption': 'Trust Govt Corruption', 'Freedom to make life choices' : 'Freedom', 'Social support':'Family'})
data_2019 = data_2019[desired_order]
data_2019.head()
# Out:
#    Happiness Rank      Country  Happiness Score  GDP per Capita  Family  \
# 0               1      Finland            7.769           1.340   1.587
# 1               2      Denmark            7.600           1.383   1.573
# 2               3       Norway            7.554           1.488   1.582
# 3               4      Iceland            7.494           1.380   1.624
# 4               5  Netherlands            7.488           1.396   1.522
#
#    Health Life Expectancy  Freedom  Generosity  Trust Govt Corruption  year
# 0                   0.986    0.596       0.153                  0.393  2019
# 1                   0.996    0.592       0.252                  0.410  2019
# 2                   1.028    0.603       0.271                  0.341  2019
# 3                   1.026    0.591       0.354                  0.118  2019
# 4                   0.999    0.557       0.322                  0.298  2019

# %% [markdown]
# #### Concat all into one dataframe

# %%
# List of DataFrames for each year
data_frames = [data_2015, data_2016, data_2017, data_2018, data_2019]  

# Merge the DataFrames iteratively
merged_df = data_frames[0]  # Start with the first DataFrame
for i in range(1, len(data_frames)):
    print(i)
    print(str(2015 + i - 1))
    merged_df = pd.merge(merged_df, data_frames[i], on='Country', how='outer', suffixes=('_' + str(2015 + i - 1), '_' + str(2015 + i)))

merged_df.head()
# Out:
# 1
# 2015
# 2
# 2016
# 3
# 2017
# 4
# 2018
#    Happiness Rank_2015      Country  Happiness Score_2015  \
# 0                  1.0  Switzerland                 7.587
# 1                  2.0      Iceland                 7.561
# 2                  3.0      Denmark                 7.527
# 3                  4.0       Norway                 7.522
# 4                  5.0       Canada                 7.427
#
#    GDP per Capita_2015  Family_2015  Health Life Expectancy_2015  \
# 0              1.39651      1.34951                      0.94143
# 1              1.30232      1.40223                      0.94784
# 2              1.32548      1.36058                      0.87464
# 3              1.45900      1.33095                      0.88521
# 4              1.32629      1.32261                      0.90563
#
#    Freedom_2015  Generosity_2015  Trust Govt Corruption_2015  year_2015  ...  \
# 0       0.66557          0.29678                     0.41978     2015.0  ...
# ...

# %%
# Get all column headings
column_headings = merged_df.columns.tolist()

# Display the column headings
print(column_headings)
# Out:
# ['Happiness Rank_2015', 'Country', 'Happiness Score_2015', 'GDP per Capita_2015', 'Family_2015', 'Health Life Expectancy_2015', 'Freedom_2015', 'Generosity_2015', 'Trust Govt Corruption_2015', 'year_2015', 'Happiness Rank_2016', 'Happiness Score_2016', 'GDP per Capita_2016', 'Family_2016', 'Health Life Expectancy_2016', 'Freedom_2016', 'Generosity_2016', 'Trust Govt Corruption_2016', 'year_2016', 'Happiness Rank_2017', 'Happiness Score_2017', 'GDP per Capita_2017', 'Family_2017', 'Health Life Expectancy_2017', 'Freedom_2017', 'Generosity_2017', 'Trust Govt Corruption_2017', 'year_2017', 'Happiness Rank_2018', 'Happiness Score_2018', 'GDP per Capita_2018', 'Family_2018', 'Health Life Expectancy_2018', 'Freedom_2018', 'Generosity_2018', 'Trust Govt Corruption_2018', 'year_2018', 'Happiness Rank', 'Happiness Score', 'GDP per Capita', 'Family', 'Health Life Expectancy', 'Freedom', 'Generosity', 'Trust Govt Corruption', 'year']

# %% [markdown]
# #### Sort the merged DF by 2019 Happiness Rank and lets study the top 30 nations

# %%
sorted_df = merged_df.sort_values(['Happiness Rank'])
sorted_df.head()
# Out:
#    Happiness Rank_2015      Country  Happiness Score_2015  \
# 5                  6.0      Finland                 7.406
# 2                  3.0      Denmark                 7.527
# 3                  4.0       Norway                 7.522
# 1                  2.0      Iceland                 7.561
# 6                  7.0  Netherlands                 7.378
#
#    GDP per Capita_2015  Family_2015  Health Life Expectancy_2015  \
# 5              1.29025      1.31826                      0.88911
# 2              1.32548      1.36058                      0.87464
# 3              1.45900      1.33095                      0.88521
# 1              1.30232      1.40223                      0.94784
# 6              1.32944      1.28017                      0.89284
#
#    Freedom_2015  Generosity_2015  Trust Govt Corruption_2015  year_2015  ...  \
# 5       0.64169          0.23351                     0.41372     2015.0  ...
# ...

# %%
top_20 = sorted_df[:20]
top_20.head()
# Out:
#    Happiness Rank_2015      Country  Happiness Score_2015  \
# 5                  6.0      Finland                 7.406
# 2                  3.0      Denmark                 7.527
# 3                  4.0       Norway                 7.522
# 1                  2.0      Iceland                 7.561
# 6                  7.0  Netherlands                 7.378
#
#    GDP per Capita_2015  Family_2015  Health Life Expectancy_2015  \
# 5              1.29025      1.31826                      0.88911
# 2              1.32548      1.36058                      0.87464
# 3              1.45900      1.33095                      0.88521
# 1              1.30232      1.40223                      0.94784
# 6              1.32944      1.28017                      0.89284
#
#    Freedom_2015  Generosity_2015  Trust Govt Corruption_2015  year_2015  ...  \
# 5       0.64169          0.23351                     0.41372     2015.0  ...
# ...

# %% [markdown]
# #### Lets visualize the top twenty Happy Nations and year over year change

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
concat_df = pd.concat(data_frames)
concat_df.head()
# Out:
#    Happiness Rank      Country  Happiness Score  GDP per Capita   Family  \
# 0               1  Switzerland            7.587         1.39651  1.34951
# 1               2      Iceland            7.561         1.30232  1.40223
# 2               3      Denmark            7.527         1.32548  1.36058
# 3               4       Norway            7.522         1.45900  1.33095
# 4               5       Canada            7.427         1.32629  1.32261
#
#    Health Life Expectancy  Freedom  Generosity  Trust Govt Corruption  year
# 0                 0.94143  0.66557     0.29678                0.41978  2015
# 1                 0.94784  0.62877     0.43630                0.14145  2015
# 2                 0.87464  0.64938     0.34139                0.48357  2015
# 3                 0.88521  0.66973     0.34699                0.36503  2015
# 4                 0.90563  0.63297     0.45811                0.32957  2015

# %%
top_20_cntry_data = concat_df.loc[concat_df.Country.isin(data_2019.sort_values('Happiness Rank')[:20]['Country'])]
top_20_cntry_data.head()
#reviews.loc[reviews.country.isin(['Italy', 'France'])]
# Out:
#    Happiness Rank      Country  Happiness Score  GDP per Capita   Family  \
# 0               1  Switzerland            7.587         1.39651  1.34951
# 1               2      Iceland            7.561         1.30232  1.40223
# 2               3      Denmark            7.527         1.32548  1.36058
# 3               4       Norway            7.522         1.45900  1.33095
# 4               5       Canada            7.427         1.32629  1.32261
#
#    Health Life Expectancy  Freedom  Generosity  Trust Govt Corruption  year
# 0                 0.94143  0.66557     0.29678                0.41978  2015
# 1                 0.94784  0.62877     0.43630                0.14145  2015
# 2                 0.87464  0.64938     0.34139                0.48357  2015
# 3                 0.88521  0.66973     0.34699                0.36503  2015
# 4                 0.90563  0.63297     0.45811                0.32957  2015

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,6))

# Bar Chart showing average arrival delay for Spirit Airlines airline code = NK flights by month
ax = sns.barplot(x=top_20_cntry_data.Country, y=top_20_cntry_data['Happiness Score'])
# Rotate x-labels vertically
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# Add label for vertical axis
plt.ylabel("Happiness Score")
# Out:
# Text(0, 0.5, 'Happiness Score')

# %% [markdown]
# ### Plot Finland for multiple years

# %%
finland_data = concat_df.loc[concat_df.Country == 'Finland']
finland_data
# Out:
#    Happiness Rank  Country  Happiness Score  GDP per Capita    Family  \
# 5               6  Finland            7.406        1.290250  1.318260
# 4               5  Finland            7.413        1.405980  1.134640
# 4               5  Finland            7.469        1.443572  1.540247
# 0               1  Finland            7.632        1.305000  1.592000
# 0               1  Finland            7.769        1.340000  1.587000
#
#    Health Life Expectancy   Freedom  Generosity  Trust Govt Corruption  year
# 5                0.889110  0.641690    0.233510               0.413720  2015
# 4                0.810910  0.571040    0.254920               0.410040  2016
# 4                0.809158  0.617951    0.245483               0.382612  2017
# 0                0.874000  0.681000    0.202000               0.393000  2018
# 0                0.986000  0.596000    0.153000               0.393000  2019

# %%
concat_df['year'] = pd.to_numeric(concat_df['year'], errors='coerce')
concat_df
# Out:
#      Happiness Rank                   Country  Happiness Score  \
# 0                 1               Switzerland            7.587
# 1                 2                   Iceland            7.561
# 2                 3                   Denmark            7.527
# 3                 4                    Norway            7.522
# 4                 5                    Canada            7.427
# ..              ...                       ...              ...
# 151             152                    Rwanda            3.334
# 152             153                  Tanzania            3.231
# 153             154               Afghanistan            3.203
# 154             155  Central African Republic            3.083
# 155             156               South Sudan            2.853
#
#      GDP per Capita   Family  Health Life Expectancy  Freedom  Generosity  \
# 0           1.39651  1.34951                 0.94143  0.66557     0.29678
# ...

# %%
ax = sns.lineplot(data=concat_df.loc[concat_df.Country.isin(top_20_cntry_data.Country[:10])], x="year", y="Happiness Rank", hue='Country')

# Move the legend to the side
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Convert x-axis labels to integers (years)
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{int(x)}'))
#['Finland', 'Iceland', 'Switzerland', 'Norway', Newzealand]
