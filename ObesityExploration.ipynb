# %% [markdown]
# <a href="https://colab.research.google.com/github/codekunoichi/learning-datascience/blob/master/ObesityExploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Ingest

# %% [markdown]
# [CDC Data on relation between physical activity and Obesity ](https://chronicdata.cdc.gov/Nutrition-Physical-Activity-and-Obesity/Nutrition-Physical-Activity-and-Obesity-Behavioral/hn4x-zwk7)

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/codekunoichi/learning-datascience/master/data-files/Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv")
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2020     2020           US     National
# 1       2014     2014           GU         Guam
# 2       2013     2013           US     National
# 3       2013     2013           US     National
# 4       2015     2015           US     National
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System        Physical Activity
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                           Topic  \
# 0  Physical Activity - Behavior
# 1       Obesity / Weight Status
# 2       Obesity / Weight Status
# 3       Obesity / Weight Status
# 4  Physical Activity - Behavior
#
# ...

# %% [markdown]
# Last 5 rows

# %%
df.tail()
# Out:
#        YearStart  YearEnd LocationAbbr  LocationDesc  \
# 88624       2021     2021           ND  North Dakota
# 88625       2021     2021           PR   Puerto Rico
# 88626       2021     2021           WI     Wisconsin
# 88627       2021     2021           UT          Utah
# 88628       2021     2021           US      National
#
#                                        Datasource                  Class  \
# 88624  Behavioral Risk Factor Surveillance System  Fruits and Vegetables
# 88625  Behavioral Risk Factor Surveillance System      Physical Activity
# 88626  Behavioral Risk Factor Surveillance System      Physical Activity
# 88627  Behavioral Risk Factor Surveillance System  Fruits and Vegetables
# 88628  Behavioral Risk Factor Surveillance System      Physical Activity
#
#                                   Topic  \
# 88624  Fruits and Vegetables - Behavior
# 88625      Physical Activity - Behavior
# 88626      Physical Activity - Behavior
# ...

# %% [markdown]
# Let explore the columns

# %%
df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
#        'Sample_Size', 'Total', 'Age(years)', 'Education', 'Gender', 'Income',
#        'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'LocationID', 'StratificationCategory1',
#        'Stratification1', 'StratificationCategoryId1', 'StratificationID1'],
#       dtype='object')

# %% [markdown]
# Lets examine how many rows and columns are present

# %%
df.shape
# Out:
# (88629, 33)

# %% [markdown]
# # EDA - Exploratory Data Analysis

# %% [markdown]
# Lets explore the general characteristics of the data

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        YearStart  YearEnd LocationAbbr  LocationDesc  \
# 0           2020     2020           US      National
# 1           2014     2014           GU          Guam
# 2           2013     2013           US      National
# 3           2013     2013           US      National
# 4           2015     2015           US      National
# ...          ...      ...          ...           ...
# 88624       2021     2021           ND  North Dakota
# 88625       2021     2021           PR   Puerto Rico
# 88626       2021     2021           WI     Wisconsin
# 88627       2021     2021           UT          Utah
# 88628       2021     2021           US      National
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System        Physical Activity
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...

# %% [markdown]
# # Modelling

# %% [markdown]
# # Conclusion
